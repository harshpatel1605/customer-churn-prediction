# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../data/processed/churn_fe_data.csv")

# %%
X = df.drop("Churn", axis=1)
y = df["Churn"]

# %%
X.shape
# Out:
# (7032, 28)

# %%
X.columns.duplicated().sum()
# Out:
# np.int64(0)

# %%
X.nunique().sort_values()
# Out:
# gender                                      2
# high_spender                                2
# early_customer                              2
# PaymentMethod_Mailed check                  2
# PaymentMethod_Electronic check              2
# PaymentMethod_Credit card (automatic)       2
# StreamingMovies_Yes                         2
# StreamingTV_Yes                             2
# TechSupport_Yes                             2
# DeviceProtection_Yes                        2
# OnlineSecurity_Yes                          2
# OnlineBackup_Yes                            2
# InternetService_Fiber optic                 2
# MultipleLines_Yes                           2
# MultipleLines_No phone service              2
# PaperlessBilling                            2
# PhoneService                                2
# Dependents                                  2
# Partner                                     2
# SeniorCitizen                               2
# InternetService_No                          2
# contract_risk                               3
# tenure_risk                                 4
# service_count                               9
# tenure                                     72
# contract_tenure_risk                       75
# MonthlyCharges                             99
# avg_monthly_charge                       4157
# dtype: int64

# %%
corr = df.corr()["Churn"].sort_values(ascending=False)
corr
# Out:
# Churn                                    1.000000
# contract_risk                            0.396150
# contract_tenure_risk                     0.364451
# tenure_risk                              0.347133
# early_customer                           0.319628
# InternetService_Fiber optic              0.307463
# PaymentMethod_Electronic check           0.301455
# MonthlyCharges                           0.192922
# PaperlessBilling                         0.191454
# SeniorCitizen                            0.150541
# avg_monthly_charge                       0.070157
# StreamingTV_Yes                          0.063254
# high_spender                             0.062342
# StreamingMovies_Yes                      0.060860
# MultipleLines_Yes                        0.040033
# PhoneService                             0.011691
# gender                                  -0.008545
# MultipleLines_No phone service          -0.011691
# DeviceProtection_Yes                    -0.066193
# service_count                           -0.067459
# OnlineBackup_Yes                        -0.082307
# PaymentMethod_Mailed check              -0.090773
# PaymentMethod_Credit card (automatic)   -0.134687
# Partner                                 -0.149982
# Dependents                              -0.163128
# TechSupport_Yes                         -0.164716
# OnlineSecurity_Yes                      -0.171270
# InternetService_No                      -0.227578
# tenure                                  -0.354049
# Name: Churn, dtype: float64

# %%
low_corr_features = corr[abs(corr) < 0.01].index
low_corr_features
# Out:
# Index(['gender'], dtype='object')

# %%
X.shape
# Out:
# (7032, 28)

# %%
X.drop(columns=low_corr_features, inplace=True)

# %%
X.shape
# Out:
# (7032, 27)

# %%
df[["contract_risk", "contract_tenure_risk"]].corr()
# Out:
#                       contract_risk  contract_tenure_risk
# contract_risk              1.000000              0.488425
# contract_tenure_risk       0.488425              1.000000

# %%
corr_matrix = X.corr().abs()
corr_matrix
# Out:
#                                        SeniorCitizen   Partner  Dependents  \
# SeniorCitizen                               1.000000  0.016957    0.210550
# Partner                                     0.016957  1.000000    0.452269
# Dependents                                  0.210550  0.452269    1.000000
# tenure                                      0.015683  0.381912    0.163386
# PhoneService                                0.008392  0.018397    0.001078
# PaperlessBilling                            0.156258  0.013957    0.110131
# MonthlyCharges                              0.219829  0.097890    0.112360
# MultipleLines_No phone service              0.008392  0.018397    0.001078
# MultipleLines_Yes                           0.142996  0.142561    0.024307
# InternetService_Fiber optic                 0.254923  0.001235    0.164101
# InternetService_No                          0.182519  0.000286    0.138383
# OnlineSecurity_Yes                          0.038576  0.143346    0.080786
# OnlineBackup_Yes                            0.066663  0.141849    0.023639
# DeviceProtection_Yes                        0.059514  0.153556    0.013900
# TechSupport_Yes                             0.060577  0.120206    0.063053
# StreamingTV_Yes                             0.105445  0.124483    0.016499
# StreamingMovies_Yes                         0.119842  0.118108    0.038375
# PaymentMethod_Credit card (automatic)       0.024359  0.082327    0.061134
# PaymentMethod_Electronic check              0.171322  0.083207    0.149274
# PaymentMethod_Mailed check                  0.152987  0.096948    0.056448
# service_count                               0.095943  0.220032    0.021304
# tenure_risk                                 0.023317  0.363275    0.156880
# early_customer                              0.027713  0.305061    0.145379
# avg_monthly_charge                          0.201471  0.170835    0.065052
# high_spender                                0.177991  0.150782    0.048485
# contract_risk                               0.141820  0.294094    0.240556
# contract_tenure_risk                        0.004100  0.310220    0.164075
#
#                                          tenure  PhoneService  \
# SeniorCitizen                          0.015683      0.008392
# Partner                                0.381912      0.018397
# Dependents                             0.163386      0.001078
# tenure                                 1.000000      0.007877
# PhoneService                           0.007877      1.000000
# PaperlessBilling                       0.004823      0.016696
# MonthlyCharges                         0.246876      0.247918
# MultipleLines_No phone service         0.007877      1.000000
# MultipleLines_Yes                      0.332399      0.279530
# InternetService_Fiber optic            0.017930      0.290183
# InternetService_No                     0.037529      0.171817
# OnlineSecurity_Yes                     0.328297      0.091676
# OnlineBackup_Yes                       0.361138      0.052133
# DeviceProtection_Yes                   0.361520      0.070076
# TechSupport_Yes                        0.325288      0.095138
# StreamingTV_Yes                        0.280264      0.021383
# StreamingMovies_Yes                    0.285402      0.033477
# PaymentMethod_Credit card (automatic)  0.232800      0.006916
# PaymentMethod_Electronic check         0.210197      0.002747
# PaymentMethod_Mailed check             0.232181      0.004463
# service_count                          0.524441      0.128129
# tenure_risk                            0.961134      0.005827
# early_customer                         0.754330      0.006950
# avg_monthly_charge                     0.413232      0.221429
# high_spender                           0.346186      0.297855
# contract_risk                          0.676734      0.003019
# contract_tenure_risk                   0.673437      0.001470
#
#                                        PaperlessBilling  MonthlyCharges  \
# SeniorCitizen                                  0.156258        0.219829
# Partner                                        0.013957        0.097890
# Dependents                                     0.110131        0.112360
# tenure                                         0.004823        0.246876
# PhoneService                                   0.016696        0.247918
# PaperlessBilling                               1.000000        0.351923
# MonthlyCharges                                 0.351923        1.000000
# MultipleLines_No phone service                 0.016696        0.247918
# MultipleLines_Yes                              0.163746        0.490986
# InternetService_Fiber optic                    0.326470        0.787196
# InternetService_No                             0.320592        0.763146
# OnlineSecurity_Yes                             0.004051        0.296487
# OnlineBackup_Yes                               0.127056        0.441443
# DeviceProtection_Yes                           0.104079        0.482558
# TechSupport_Yes                                0.037536        0.338320
# StreamingTV_Yes                                0.224241        0.629624
# StreamingMovies_Yes                            0.211583        0.627228
# PaymentMethod_Credit card (automatic)          0.013726        0.030277
# PaymentMethod_Electronic check                 0.208427        0.271238
# PaymentMethod_Mailed check                     0.203981        0.376615
# service_count                                  0.205167        0.802340
# tenure_risk                                    0.004291        0.237278
# early_customer                                 0.003860        0.191927
# avg_monthly_charge                             0.315956        0.956830
# high_spender                                   0.257576        0.818740
# contract_risk                                  0.175475        0.072685
# contract_tenure_risk                           0.012919        0.165759
#
#                                        MultipleLines_No phone service  \
# SeniorCitizen                                                0.008392
# Partner                                                      0.018397
# Dependents                                                   0.001078
# tenure                                                       0.007877
# PhoneService                                                 1.000000
# PaperlessBilling                                             0.016696
# MonthlyCharges                                               0.247918
# MultipleLines_No phone service                               1.000000
# MultipleLines_Yes                                            0.279530
# InternetService_Fiber optic                                  0.290183
# InternetService_No                                           0.171817
# OnlineSecurity_Yes                                           0.091676
# OnlineBackup_Yes                                             0.052133
# DeviceProtection_Yes                                         0.070076
# TechSupport_Yes                                              0.095138
# StreamingTV_Yes                                              0.021383
# StreamingMovies_Yes                                          0.033477
# PaymentMethod_Credit card (automatic)                        0.006916
# PaymentMethod_Electronic check                               0.002747
# PaymentMethod_Mailed check                                   0.004463
# service_count                                                0.128129
# tenure_risk                                                  0.005827
# early_customer                                               0.006950
# avg_monthly_charge                                           0.221429
# high_spender                                                 0.297855
# contract_risk                                                0.003019
# contract_tenure_risk                                         0.001470
#
#                                        MultipleLines_Yes  \
# SeniorCitizen                                   0.142996
# Partner                                         0.142561
# Dependents                                      0.024307
# tenure                                          0.332399
# PhoneService                                    0.279530
# PaperlessBilling                                0.163746
# MonthlyCharges                                  0.490986
# MultipleLines_No phone service                  0.279530
# MultipleLines_Yes                               1.000000
# InternetService_Fiber optic                     0.366420
# InternetService_No                              0.210794
# OnlineSecurity_Yes                              0.098592
# OnlineBackup_Yes                                0.202228
# DeviceProtection_Yes                            0.201733
# TechSupport_Yes                                 0.100421
# StreamingTV_Yes                                 0.257804
# StreamingMovies_Yes                             0.259194
# PaymentMethod_Credit card (automatic)           0.060319
# PaymentMethod_Electronic check                  0.083583
# PaymentMethod_Mailed check                      0.227672
# service_count                                   0.538484
# tenure_risk                                     0.315664
# early_customer                                  0.263331
# avg_monthly_charge                              0.520480
# high_spender                                    0.486404
# contract_risk                                   0.107529
# contract_tenure_risk                            0.249967
#
#                                        InternetService_Fiber optic  ...  \
# SeniorCitizen                                             0.254923  ...
# Partner                                                   0.001235  ...
# Dependents                                                0.164101  ...
# tenure                                                    0.017930  ...
# PhoneService                                              0.290183  ...
# PaperlessBilling                                          0.326470  ...
# MonthlyCharges                                            0.787196  ...
# MultipleLines_No phone service                            0.290183  ...
# MultipleLines_Yes                                         0.366420  ...
# InternetService_Fiber optic                               1.000000  ...
# InternetService_No                                        0.465736  ...
# OnlineSecurity_Yes                                        0.030506  ...
# OnlineBackup_Yes                                          0.165940  ...
# DeviceProtection_Yes                                      0.176356  ...
# TechSupport_Yes                                           0.020299  ...
# StreamingTV_Yes                                           0.329744  ...
# StreamingMovies_Yes                                       0.322457  ...
# PaymentMethod_Credit card (automatic)                     0.050552  ...
# PaymentMethod_Electronic check                            0.335763  ...
# PaymentMethod_Mailed check                                0.305984  ...
# service_count                                             0.351094  ...
# tenure_risk                                               0.023197  ...
# early_customer                                            0.021441  ...
# avg_monthly_charge                                        0.708313  ...
# high_spender                                              0.642944  ...
# contract_risk                                             0.252733  ...
# contract_tenure_risk                                      0.002568  ...
#
#                                        PaymentMethod_Credit card (automatic)  \
# SeniorCitizen                                                       0.024359
# Partner                                                             0.082327
# Dependents                                                          0.061134
# tenure                                                              0.232800
# PhoneService                                                        0.006916
# PaperlessBilling                                                    0.013726
# MonthlyCharges                                                      0.030277
# MultipleLines_No phone service                                      0.006916
# MultipleLines_Yes                                                   0.060319
# InternetService_Fiber optic                                         0.050552
# InternetService_No                                                  0.001870
# OnlineSecurity_Yes                                                  0.115473
# OnlineBackup_Yes                                                    0.090455
# DeviceProtection_Yes                                                0.111252
# TechSupport_Yes                                                     0.117024
# StreamingTV_Yes                                                     0.040010
# StreamingMovies_Yes                                                 0.048398
# PaymentMethod_Credit card (automatic)                               1.000000
# PaymentMethod_Electronic check                                      0.373978
# PaymentMethod_Mailed check                                          0.285583
# service_count                                                       0.131893
# tenure_risk                                                         0.221508
# early_customer                                                      0.184165
# avg_monthly_charge                                                  0.077110
# high_spender                                                        0.069481
# contract_risk                                                       0.211786
# contract_tenure_risk                                                0.187844
#
#                                        PaymentMethod_Electronic check  \
# SeniorCitizen                                                0.171322
# Partner                                                      0.083207
# Dependents                                                   0.149274
# tenure                                                       0.210197
# PhoneService                                                 0.002747
# PaperlessBilling                                             0.208427
# MonthlyCharges                                               0.271238
# MultipleLines_No phone service                               0.002747
# MultipleLines_Yes                                            0.083583
# InternetService_Fiber optic                                  0.335763
# InternetService_No                                           0.284608
# OnlineSecurity_Yes                                           0.112295
# OnlineBackup_Yes                                             0.000364
# DeviceProtection_Yes                                         0.003308
# TechSupport_Yes                                              0.114807
# StreamingTV_Yes                                              0.144747
# StreamingMovies_Yes                                          0.137420
# PaymentMethod_Credit card (automatic)                        0.373978
# PaymentMethod_Electronic check                               1.000000
# PaymentMethod_Mailed check                                   0.386971
# service_count                                                0.036306
# tenure_risk                                                  0.195134
# early_customer                                               0.160530
# avg_monthly_charge                                           0.190158
# high_spender                                                 0.148803
# contract_risk                                                0.341687
# contract_tenure_risk                                         0.176737
#
#                                        PaymentMethod_Mailed check  \
# SeniorCitizen                                            0.152987
# Partner                                                  0.096948
# Dependents                                               0.056448
# tenure                                                   0.232181
# PhoneService                                             0.004463
# PaperlessBilling                                         0.203981
# MonthlyCharges                                           0.376615
# MultipleLines_No phone service                           0.004463
# MultipleLines_Yes                                        0.227672
# InternetService_Fiber optic                              0.305984
# InternetService_No                                       0.319694
# OnlineSecurity_Yes                                       0.079918
# OnlineBackup_Yes                                         0.174075
# DeviceProtection_Yes                                     0.187325
# TechSupport_Yes                                          0.084631
# StreamingTV_Yes                                          0.247712
# StreamingMovies_Yes                                      0.250290
# PaymentMethod_Credit card (automatic)                    0.285583
# PaymentMethod_Electronic check                           0.386971
# PaymentMethod_Mailed check                               1.000000
# service_count                                            0.292205
# tenure_risk                                              0.223929
# early_customer                                           0.183222
# avg_monthly_charge                                       0.378297
# high_spender                                             0.321187
# contract_risk                                            0.007512
# contract_tenure_risk                                     0.168156
#
#                                        service_count  tenure_risk  \
# SeniorCitizen                               0.095943     0.023317
# Partner                                     0.220032     0.363275
# Dependents                                  0.021304     0.156880
# tenure                                      0.524441     0.961134
# PhoneService                                0.128129     0.005827
# PaperlessBilling                            0.205167     0.004291
# MonthlyCharges                              0.802340     0.237278
# MultipleLines_No phone service              0.128129     0.005827
# MultipleLines_Yes                           0.538484     0.315664
# InternetService_Fiber optic                 0.351094     0.023197
# InternetService_No                          0.544928     0.038996
# OnlineSecurity_Yes                          0.522106     0.303628
# OnlineBackup_Yes                            0.599388     0.342960
# DeviceProtection_Yes                        0.659119     0.339013
# TechSupport_Yes                             0.584316     0.303832
# StreamingTV_Yes                             0.674994     0.268796
# StreamingMovies_Yes                         0.678211     0.273160
# PaymentMethod_Credit card (automatic)       0.131893     0.221508
# PaymentMethod_Electronic check              0.036306     0.195134
# PaymentMethod_Mailed check                  0.292205     0.223929
# service_count                               1.000000     0.495033
# tenure_risk                                 0.495033     1.000000
# early_customer                              0.398893     0.848486
# avg_monthly_charge                          0.849760     0.407529
# high_spender                                0.714969     0.343935
# contract_risk                               0.281522     0.621770
# contract_tenure_risk                        0.387386     0.686685
#
#                                        early_customer  avg_monthly_charge  \
# SeniorCitizen                                0.027713            0.201471
# Partner                                      0.305061            0.170835
# Dependents                                   0.145379            0.065052
# tenure                                       0.754330            0.413232
# PhoneService                                 0.006950            0.221429
# PaperlessBilling                             0.003860            0.315956
# MonthlyCharges                               0.191927            0.956830
# MultipleLines_No phone service               0.006950            0.221429
# MultipleLines_Yes                            0.263331            0.520480
# InternetService_Fiber optic                  0.021441            0.708313
# InternetService_No                           0.027554            0.691850
# OnlineSecurity_Yes                           0.242409            0.343735
# OnlineBackup_Yes                             0.267366            0.482343
# DeviceProtection_Yes                         0.273920            0.523511
# TechSupport_Yes                              0.238628            0.383928
# StreamingTV_Yes                              0.220761            0.638127
# StreamingMovies_Yes                          0.221388            0.639436
# PaymentMethod_Credit card (automatic)        0.184165            0.077110
# PaymentMethod_Electronic check               0.160530            0.190158
# PaymentMethod_Mailed check                   0.183222            0.378297
# service_count                                0.398893            0.849760
# tenure_risk                                  0.848486            0.407529
# early_customer                               1.000000            0.379822
# avg_monthly_charge                           0.379822            1.000000
# high_spender                                 0.337179            0.874148
# contract_risk                                0.464949            0.047345
# contract_tenure_risk                         0.757564            0.406249
#
#                                        high_spender  contract_risk  \
# SeniorCitizen                              0.177991       0.141820
# Partner                                    0.150782       0.294094
# Dependents                                 0.048485       0.240556
# tenure                                     0.346186       0.676734
# PhoneService                               0.297855       0.003019
# PaperlessBilling                           0.257576       0.175475
# MonthlyCharges                             0.818740       0.072685
# MultipleLines_No phone service             0.297855       0.003019
# MultipleLines_Yes                          0.486404       0.107529
# InternetService_Fiber optic                0.642944       0.252733
# InternetService_No                         0.524384       0.241574
# OnlineSecurity_Yes                         0.263521       0.245660
# OnlineBackup_Yes                           0.387276       0.155262
# DeviceProtection_Yes                       0.417178       0.219648
# TechSupport_Yes                            0.295471       0.293967
# StreamingTV_Yes                            0.519437       0.104178
# StreamingMovies_Yes                        0.528962       0.109136
# PaymentMethod_Credit card (automatic)      0.069481       0.211786
# PaymentMethod_Electronic check             0.148803       0.341687
# PaymentMethod_Mailed check                 0.321187       0.007512
# service_count                              0.714969       0.281522
# tenure_risk                                0.343935       0.621770
# early_customer                             0.337179       0.464949
# avg_monthly_charge                         0.874148       0.047345
# high_spender                               1.000000       0.034983
# contract_risk                              0.034983       1.000000
# contract_tenure_risk                       0.376761       0.488425
#
#                                        contract_tenure_risk
# SeniorCitizen                                      0.004100
# Partner                                            0.310220
# Dependents                                         0.164075
# tenure                                             0.673437
# PhoneService                                       0.001470
# PaperlessBilling                                   0.012919
# MonthlyCharges                                     0.165759
# MultipleLines_No phone service                     0.001470
# MultipleLines_Yes                                  0.249967
# InternetService_Fiber optic                        0.002568
# InternetService_No                                 0.003144
# OnlineSecurity_Yes                                 0.237041
# OnlineBackup_Yes                                   0.249275
# DeviceProtection_Yes                               0.265938
# TechSupport_Yes                                    0.244979
# StreamingTV_Yes                                    0.215359
# StreamingMovies_Yes                                0.219456
# PaymentMethod_Credit card (automatic)              0.187844
# PaymentMethod_Electronic check                     0.176737
# PaymentMethod_Mailed check                         0.168156
# service_count                                      0.387386
# tenure_risk                                        0.686685
# early_customer                                     0.757564
# avg_monthly_charge                                 0.406249
# high_spender                                       0.376761
# contract_risk                                      0.488425
# contract_tenure_risk                               1.000000
#
# [27 rows x 27 columns]

# %%
upper = corr_matrix.where(
    np.triu(np.ones(corr_matrix.shape), k=1).astype(bool)
)

upper
# Out:
#                                        SeniorCitizen   Partner  Dependents  \
# SeniorCitizen                                    NaN  0.016957    0.210550
# Partner                                          NaN       NaN    0.452269
# Dependents                                       NaN       NaN         NaN
# tenure                                           NaN       NaN         NaN
# PhoneService                                     NaN       NaN         NaN
# PaperlessBilling                                 NaN       NaN         NaN
# MonthlyCharges                                   NaN       NaN         NaN
# MultipleLines_No phone service                   NaN       NaN         NaN
# MultipleLines_Yes                                NaN       NaN         NaN
# InternetService_Fiber optic                      NaN       NaN         NaN
# InternetService_No                               NaN       NaN         NaN
# OnlineSecurity_Yes                               NaN       NaN         NaN
# OnlineBackup_Yes                                 NaN       NaN         NaN
# DeviceProtection_Yes                             NaN       NaN         NaN
# TechSupport_Yes                                  NaN       NaN         NaN
# StreamingTV_Yes                                  NaN       NaN         NaN
# StreamingMovies_Yes                              NaN       NaN         NaN
# PaymentMethod_Credit card (automatic)            NaN       NaN         NaN
# PaymentMethod_Electronic check                   NaN       NaN         NaN
# PaymentMethod_Mailed check                       NaN       NaN         NaN
# service_count                                    NaN       NaN         NaN
# tenure_risk                                      NaN       NaN         NaN
# early_customer                                   NaN       NaN         NaN
# avg_monthly_charge                               NaN       NaN         NaN
# high_spender                                     NaN       NaN         NaN
# contract_risk                                    NaN       NaN         NaN
# contract_tenure_risk                             NaN       NaN         NaN
#
#                                          tenure  PhoneService  \
# SeniorCitizen                          0.015683      0.008392
# Partner                                0.381912      0.018397
# Dependents                             0.163386      0.001078
# tenure                                      NaN      0.007877
# PhoneService                                NaN           NaN
# PaperlessBilling                            NaN           NaN
# MonthlyCharges                              NaN           NaN
# MultipleLines_No phone service              NaN           NaN
# MultipleLines_Yes                           NaN           NaN
# InternetService_Fiber optic                 NaN           NaN
# InternetService_No                          NaN           NaN
# OnlineSecurity_Yes                          NaN           NaN
# OnlineBackup_Yes                            NaN           NaN
# DeviceProtection_Yes                        NaN           NaN
# TechSupport_Yes                             NaN           NaN
# StreamingTV_Yes                             NaN           NaN
# StreamingMovies_Yes                         NaN           NaN
# PaymentMethod_Credit card (automatic)       NaN           NaN
# PaymentMethod_Electronic check              NaN           NaN
# PaymentMethod_Mailed check                  NaN           NaN
# service_count                               NaN           NaN
# tenure_risk                                 NaN           NaN
# early_customer                              NaN           NaN
# avg_monthly_charge                          NaN           NaN
# high_spender                                NaN           NaN
# contract_risk                               NaN           NaN
# contract_tenure_risk                        NaN           NaN
#
#                                        PaperlessBilling  MonthlyCharges  \
# SeniorCitizen                                  0.156258        0.219829
# Partner                                        0.013957        0.097890
# Dependents                                     0.110131        0.112360
# tenure                                         0.004823        0.246876
# PhoneService                                   0.016696        0.247918
# PaperlessBilling                                    NaN        0.351923
# MonthlyCharges                                      NaN             NaN
# MultipleLines_No phone service                      NaN             NaN
# MultipleLines_Yes                                   NaN             NaN
# InternetService_Fiber optic                         NaN             NaN
# InternetService_No                                  NaN             NaN
# OnlineSecurity_Yes                                  NaN             NaN
# OnlineBackup_Yes                                    NaN             NaN
# DeviceProtection_Yes                                NaN             NaN
# TechSupport_Yes                                     NaN             NaN
# StreamingTV_Yes                                     NaN             NaN
# StreamingMovies_Yes                                 NaN             NaN
# PaymentMethod_Credit card (automatic)               NaN             NaN
# PaymentMethod_Electronic check                      NaN             NaN
# PaymentMethod_Mailed check                          NaN             NaN
# service_count                                       NaN             NaN
# tenure_risk                                         NaN             NaN
# early_customer                                      NaN             NaN
# avg_monthly_charge                                  NaN             NaN
# high_spender                                        NaN             NaN
# contract_risk                                       NaN             NaN
# contract_tenure_risk                                NaN             NaN
#
#                                        MultipleLines_No phone service  \
# SeniorCitizen                                                0.008392
# Partner                                                      0.018397
# Dependents                                                   0.001078
# tenure                                                       0.007877
# PhoneService                                                 1.000000
# PaperlessBilling                                             0.016696
# MonthlyCharges                                               0.247918
# MultipleLines_No phone service                                    NaN
# MultipleLines_Yes                                                 NaN
# InternetService_Fiber optic                                       NaN
# InternetService_No                                                NaN
# OnlineSecurity_Yes                                                NaN
# OnlineBackup_Yes                                                  NaN
# DeviceProtection_Yes                                              NaN
# TechSupport_Yes                                                   NaN
# StreamingTV_Yes                                                   NaN
# StreamingMovies_Yes                                               NaN
# PaymentMethod_Credit card (automatic)                             NaN
# PaymentMethod_Electronic check                                    NaN
# PaymentMethod_Mailed check                                        NaN
# service_count                                                     NaN
# tenure_risk                                                       NaN
# early_customer                                                    NaN
# avg_monthly_charge                                                NaN
# high_spender                                                      NaN
# contract_risk                                                     NaN
# contract_tenure_risk                                              NaN
#
#                                        MultipleLines_Yes  \
# SeniorCitizen                                   0.142996
# Partner                                         0.142561
# Dependents                                      0.024307
# tenure                                          0.332399
# PhoneService                                    0.279530
# PaperlessBilling                                0.163746
# MonthlyCharges                                  0.490986
# MultipleLines_No phone service                  0.279530
# MultipleLines_Yes                                    NaN
# InternetService_Fiber optic                          NaN
# InternetService_No                                   NaN
# OnlineSecurity_Yes                                   NaN
# OnlineBackup_Yes                                     NaN
# DeviceProtection_Yes                                 NaN
# TechSupport_Yes                                      NaN
# StreamingTV_Yes                                      NaN
# StreamingMovies_Yes                                  NaN
# PaymentMethod_Credit card (automatic)                NaN
# PaymentMethod_Electronic check                       NaN
# PaymentMethod_Mailed check                           NaN
# service_count                                        NaN
# tenure_risk                                          NaN
# early_customer                                       NaN
# avg_monthly_charge                                   NaN
# high_spender                                         NaN
# contract_risk                                        NaN
# contract_tenure_risk                                 NaN
#
#                                        InternetService_Fiber optic  ...  \
# SeniorCitizen                                             0.254923  ...
# Partner                                                   0.001235  ...
# Dependents                                                0.164101  ...
# tenure                                                    0.017930  ...
# PhoneService                                              0.290183  ...
# PaperlessBilling                                          0.326470  ...
# MonthlyCharges                                            0.787196  ...
# MultipleLines_No phone service                            0.290183  ...
# MultipleLines_Yes                                         0.366420  ...
# InternetService_Fiber optic                                    NaN  ...
# InternetService_No                                             NaN  ...
# OnlineSecurity_Yes                                             NaN  ...
# OnlineBackup_Yes                                               NaN  ...
# DeviceProtection_Yes                                           NaN  ...
# TechSupport_Yes                                                NaN  ...
# StreamingTV_Yes                                                NaN  ...
# StreamingMovies_Yes                                            NaN  ...
# PaymentMethod_Credit card (automatic)                          NaN  ...
# PaymentMethod_Electronic check                                 NaN  ...
# PaymentMethod_Mailed check                                     NaN  ...
# service_count                                                  NaN  ...
# tenure_risk                                                    NaN  ...
# early_customer                                                 NaN  ...
# avg_monthly_charge                                             NaN  ...
# high_spender                                                   NaN  ...
# contract_risk                                                  NaN  ...
# contract_tenure_risk                                           NaN  ...
#
#                                        PaymentMethod_Credit card (automatic)  \
# SeniorCitizen                                                       0.024359
# Partner                                                             0.082327
# Dependents                                                          0.061134
# tenure                                                              0.232800
# PhoneService                                                        0.006916
# PaperlessBilling                                                    0.013726
# MonthlyCharges                                                      0.030277
# MultipleLines_No phone service                                      0.006916
# MultipleLines_Yes                                                   0.060319
# InternetService_Fiber optic                                         0.050552
# InternetService_No                                                  0.001870
# OnlineSecurity_Yes                                                  0.115473
# OnlineBackup_Yes                                                    0.090455
# DeviceProtection_Yes                                                0.111252
# TechSupport_Yes                                                     0.117024
# StreamingTV_Yes                                                     0.040010
# StreamingMovies_Yes                                                 0.048398
# PaymentMethod_Credit card (automatic)                                    NaN
# PaymentMethod_Electronic check                                           NaN
# PaymentMethod_Mailed check                                               NaN
# service_count                                                            NaN
# tenure_risk                                                              NaN
# early_customer                                                           NaN
# avg_monthly_charge                                                       NaN
# high_spender                                                             NaN
# contract_risk                                                            NaN
# contract_tenure_risk                                                     NaN
#
#                                        PaymentMethod_Electronic check  \
# SeniorCitizen                                                0.171322
# Partner                                                      0.083207
# Dependents                                                   0.149274
# tenure                                                       0.210197
# PhoneService                                                 0.002747
# PaperlessBilling                                             0.208427
# MonthlyCharges                                               0.271238
# MultipleLines_No phone service                               0.002747
# MultipleLines_Yes                                            0.083583
# InternetService_Fiber optic                                  0.335763
# InternetService_No                                           0.284608
# OnlineSecurity_Yes                                           0.112295
# OnlineBackup_Yes                                             0.000364
# DeviceProtection_Yes                                         0.003308
# TechSupport_Yes                                              0.114807
# StreamingTV_Yes                                              0.144747
# StreamingMovies_Yes                                          0.137420
# PaymentMethod_Credit card (automatic)                        0.373978
# PaymentMethod_Electronic check                                    NaN
# PaymentMethod_Mailed check                                        NaN
# service_count                                                     NaN
# tenure_risk                                                       NaN
# early_customer                                                    NaN
# avg_monthly_charge                                                NaN
# high_spender                                                      NaN
# contract_risk                                                     NaN
# contract_tenure_risk                                              NaN
#
#                                        PaymentMethod_Mailed check  \
# SeniorCitizen                                            0.152987
# Partner                                                  0.096948
# Dependents                                               0.056448
# tenure                                                   0.232181
# PhoneService                                             0.004463
# PaperlessBilling                                         0.203981
# MonthlyCharges                                           0.376615
# MultipleLines_No phone service                           0.004463
# MultipleLines_Yes                                        0.227672
# InternetService_Fiber optic                              0.305984
# InternetService_No                                       0.319694
# OnlineSecurity_Yes                                       0.079918
# OnlineBackup_Yes                                         0.174075
# DeviceProtection_Yes                                     0.187325
# TechSupport_Yes                                          0.084631
# StreamingTV_Yes                                          0.247712
# StreamingMovies_Yes                                      0.250290
# PaymentMethod_Credit card (automatic)                    0.285583
# PaymentMethod_Electronic check                           0.386971
# PaymentMethod_Mailed check                                    NaN
# service_count                                                 NaN
# tenure_risk                                                   NaN
# early_customer                                                NaN
# avg_monthly_charge                                            NaN
# high_spender                                                  NaN
# contract_risk                                                 NaN
# contract_tenure_risk                                          NaN
#
#                                        service_count  tenure_risk  \
# SeniorCitizen                               0.095943     0.023317
# Partner                                     0.220032     0.363275
# Dependents                                  0.021304     0.156880
# tenure                                      0.524441     0.961134
# PhoneService                                0.128129     0.005827
# PaperlessBilling                            0.205167     0.004291
# MonthlyCharges                              0.802340     0.237278
# MultipleLines_No phone service              0.128129     0.005827
# MultipleLines_Yes                           0.538484     0.315664
# InternetService_Fiber optic                 0.351094     0.023197
# InternetService_No                          0.544928     0.038996
# OnlineSecurity_Yes                          0.522106     0.303628
# OnlineBackup_Yes                            0.599388     0.342960
# DeviceProtection_Yes                        0.659119     0.339013
# TechSupport_Yes                             0.584316     0.303832
# StreamingTV_Yes                             0.674994     0.268796
# StreamingMovies_Yes                         0.678211     0.273160
# PaymentMethod_Credit card (automatic)       0.131893     0.221508
# PaymentMethod_Electronic check              0.036306     0.195134
# PaymentMethod_Mailed check                  0.292205     0.223929
# service_count                                    NaN     0.495033
# tenure_risk                                      NaN          NaN
# early_customer                                   NaN          NaN
# avg_monthly_charge                               NaN          NaN
# high_spender                                     NaN          NaN
# contract_risk                                    NaN          NaN
# contract_tenure_risk                             NaN          NaN
#
#                                        early_customer  avg_monthly_charge  \
# SeniorCitizen                                0.027713            0.201471
# Partner                                      0.305061            0.170835
# Dependents                                   0.145379            0.065052
# tenure                                       0.754330            0.413232
# PhoneService                                 0.006950            0.221429
# PaperlessBilling                             0.003860            0.315956
# MonthlyCharges                               0.191927            0.956830
# MultipleLines_No phone service               0.006950            0.221429
# MultipleLines_Yes                            0.263331            0.520480
# InternetService_Fiber optic                  0.021441            0.708313
# InternetService_No                           0.027554            0.691850
# OnlineSecurity_Yes                           0.242409            0.343735
# OnlineBackup_Yes                             0.267366            0.482343
# DeviceProtection_Yes                         0.273920            0.523511
# TechSupport_Yes                              0.238628            0.383928
# StreamingTV_Yes                              0.220761            0.638127
# StreamingMovies_Yes                          0.221388            0.639436
# PaymentMethod_Credit card (automatic)        0.184165            0.077110
# PaymentMethod_Electronic check               0.160530            0.190158
# PaymentMethod_Mailed check                   0.183222            0.378297
# service_count                                0.398893            0.849760
# tenure_risk                                  0.848486            0.407529
# early_customer                                    NaN            0.379822
# avg_monthly_charge                                NaN                 NaN
# high_spender                                      NaN                 NaN
# contract_risk                                     NaN                 NaN
# contract_tenure_risk                              NaN                 NaN
#
#                                        high_spender  contract_risk  \
# SeniorCitizen                              0.177991       0.141820
# Partner                                    0.150782       0.294094
# Dependents                                 0.048485       0.240556
# tenure                                     0.346186       0.676734
# PhoneService                               0.297855       0.003019
# PaperlessBilling                           0.257576       0.175475
# MonthlyCharges                             0.818740       0.072685
# MultipleLines_No phone service             0.297855       0.003019
# MultipleLines_Yes                          0.486404       0.107529
# InternetService_Fiber optic                0.642944       0.252733
# InternetService_No                         0.524384       0.241574
# OnlineSecurity_Yes                         0.263521       0.245660
# OnlineBackup_Yes                           0.387276       0.155262
# DeviceProtection_Yes                       0.417178       0.219648
# TechSupport_Yes                            0.295471       0.293967
# StreamingTV_Yes                            0.519437       0.104178
# StreamingMovies_Yes                        0.528962       0.109136
# PaymentMethod_Credit card (automatic)      0.069481       0.211786
# PaymentMethod_Electronic check             0.148803       0.341687
# PaymentMethod_Mailed check                 0.321187       0.007512
# service_count                              0.714969       0.281522
# tenure_risk                                0.343935       0.621770
# early_customer                             0.337179       0.464949
# avg_monthly_charge                         0.874148       0.047345
# high_spender                                    NaN       0.034983
# contract_risk                                   NaN            NaN
# contract_tenure_risk                            NaN            NaN
#
#                                        contract_tenure_risk
# SeniorCitizen                                      0.004100
# Partner                                            0.310220
# Dependents                                         0.164075
# tenure                                             0.673437
# PhoneService                                       0.001470
# PaperlessBilling                                   0.012919
# MonthlyCharges                                     0.165759
# MultipleLines_No phone service                     0.001470
# MultipleLines_Yes                                  0.249967
# InternetService_Fiber optic                        0.002568
# InternetService_No                                 0.003144
# OnlineSecurity_Yes                                 0.237041
# OnlineBackup_Yes                                   0.249275
# DeviceProtection_Yes                               0.265938
# TechSupport_Yes                                    0.244979
# StreamingTV_Yes                                    0.215359
# StreamingMovies_Yes                                0.219456
# PaymentMethod_Credit card (automatic)              0.187844
# PaymentMethod_Electronic check                     0.176737
# PaymentMethod_Mailed check                         0.168156
# service_count                                      0.387386
# tenure_risk                                        0.686685
# early_customer                                     0.757564
# avg_monthly_charge                                 0.406249
# high_spender                                       0.376761
# contract_risk                                      0.488425
# contract_tenure_risk                                    NaN
#
# [27 rows x 27 columns]

# %%
to_drop = [col for col in upper.columns if any(upper[col] > 0.85)]
to_drop
# Out:
# ['MultipleLines_No phone service',
#  'tenure_risk',
#  'avg_monthly_charge',
#  'high_spender']

# %%
X.drop(columns=to_drop, inplace=True)

# %%
X.shape
# Out:
# (7032, 23)

# %%
lr = LogisticRegression(
    penalty="l1",
    solver="liblinear",
    max_iter=1000
)

lr.fit(X, y)
# Out:
# LogisticRegression(max_iter=1000, penalty='l1', solver='liblinear')

# %%
lr_selected = X.columns[lr.coef_[0] != 0]
lr_selected
# Out:
# Index(['SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService',
#        'PaperlessBilling', 'MonthlyCharges', 'MultipleLines_Yes',
#        'InternetService_Fiber optic', 'InternetService_No',
#        'OnlineSecurity_Yes', 'OnlineBackup_Yes', 'DeviceProtection_Yes',
#        'TechSupport_Yes', 'StreamingTV_Yes', 'StreamingMovies_Yes',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check',
#        'early_customer', 'contract_risk', 'contract_tenure_risk'],
#       dtype='object')

# %%
rf = RandomForestClassifier(
    n_estimators=200,
    random_state=42
)

rf.fit(X, y)

importances = pd.Series(
    rf.feature_importances_,
    index=X.columns
).sort_values(ascending=False)

importances.head(15)
# Out:
# contract_tenure_risk              0.162096
# MonthlyCharges                    0.154460
# tenure                            0.154294
# contract_risk                     0.063775
# service_count                     0.047984
# InternetService_Fiber optic       0.043952
# PaymentMethod_Electronic check    0.033144
# PaperlessBilling                  0.031718
# Partner                           0.030663
# early_customer                    0.028682
# SeniorCitizen                     0.026192
# Dependents                        0.024254
# OnlineBackup_Yes                  0.022355
# OnlineSecurity_Yes                0.022288
# TechSupport_Yes                   0.020535
# dtype: float64

# %%
final_features = list(
    set(lr_selected) |
    set(importances.head(15).index)
)

final_features
# Out:
# ['early_customer',
#  'SeniorCitizen',
#  'TechSupport_Yes',
#  'DeviceProtection_Yes',
#  'StreamingTV_Yes',
#  'StreamingMovies_Yes',
#  'tenure',
#  'contract_tenure_risk',
#  'MonthlyCharges',
#  'Dependents',
#  'OnlineBackup_Yes',
#  'PaymentMethod_Credit card (automatic)',
#  'InternetService_No',
#  'PaperlessBilling',
#  'contract_risk',
#  'OnlineSecurity_Yes',
#  'Partner',
#  'MultipleLines_Yes',
#  'InternetService_Fiber optic',
#  'PhoneService',
#  'PaymentMethod_Electronic check',
#  'service_count',
#  'PaymentMethod_Mailed check']

# %%
pd.DataFrame({"feature": final_features}).to_csv(
    "../data/processed/selected_features.csv",
    index=False
)
